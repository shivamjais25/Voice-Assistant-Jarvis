# %%
import pyttsx3
import speech_recognition as sr
import pyjokes
import webbrowser
import datetime
import time
import pyaudio

def sptext():
    recognizer=sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
        try:
            print("recognizing...")
            data=recognizer.recognize_google(audio)
            print(data)
            return data
        except sr.UnknownValueError:
            print("Not Understand")

def speechtx(x):
    engine=pyttsx3.init()
    voices = engine.getProperty('voices')
    engine.setProperty('voice',voices[1].id)
    rate = engine.getProperty('rate')
    engine.setProperty('rate',150)
    engine.say(x)
    engine.runAndWait()
    
# if __name__ == '__main__': is used for excute the main file if anyone import my file 
# so he/she doesnot able to run this code 
# It,s similar to main function in c language and main function in java


if __name__ == '__main__':
# def main():

    if "hey jarvis" in sptext().lower():
            while True :
                data1 = sptext().lower()

                if "your name" in data1:
                    name = "my name is jarvis"
                    speechtx(name)

                elif "old are you" in data1:
                    age="i am just build by you"
                    speechtx(age)

                elif 'time' in data1:
                    time = datetime.datetime.now().strftime("%I%M%p")
                    speechtx(time)

                elif 'youtube' in data1:
                    webbrowser.open("https://www.youtube.com/")
                    speechtx("opening youtube for you")

                elif "joke" in data1:
                    joke_1= pyjokes.get_joke(language="en",category="neutral")
                    print(joke_1)
                    speechtx(joke_1)

                elif "exit" in data1:
                    speechtx("thank you")
                    break

                # time.sleep(1)

    else:
        print("thanks")
# Out:
# Listening...
# recognizing...
# hey Jarvis
# Listening...
# recognizing...
# what's your name
# Listening...
# recognizing...
# old are you
# Listening...
# recognizing...
# can you make a joke for me
# How many programmers does it take to change a lightbulb? None, that's a hardware problem.
# Listening...
# recognizing...
# what's the time is it
# Listening...
# recognizing...
# open YouTube
# Listening...
# recognizing...
# exit

# %%
# !pip install SpeechRecognition
# Out:
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/32.9 MB 3.1 MB/s eta 0:00:11
#     --------------------------------------- 0.8/32.9 MB 2.9 MB/s eta 0:00:12
#     --------------------------------------- 0.8/32.9 MB 2.9 MB/s eta 0:00:12
#    - -------------------------------------- 1.6/32.9 MB 1.8 MB/s eta 0:00:17
#    -- ------------------------------------- 2.4/32.9 MB 2.2 MB/s eta 0:00:14
#    --- ------------------------------------ 3.1/32.9 MB 2.5 MB/s eta 0:00:12
#    ----- ---------------------------------- 4.5/32.9 MB 3.1 MB/s eta 0:00:10
#    ------ --------------------------------- 5.0/32.9 MB 3.3 MB/s eta 0:00:09
#    ------- -------------------------------- 6.0/32.9 MB 3.3 MB/s eta 0:00:09
#    --------- ------------------------------ 7.6/32.9 MB 3.7 MB/s eta 0:00:07
#    ---------- ----------------------------- 8.7/32.9 MB 3.8 MB/s eta 0:00:07
# ...

# %%
# !pip install pyaudio

# %%
# !pip install pyjokes

# %%
# !pip install pyttsx3
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
